# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system
    
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

add_user_message(messages, "Can you help me solve the equation 2x + 3 = 7?")
answer1 = chat(messages)
answer2 = chat(messages, system=system_prompt)

print(answer1)
print(answer2)
# Out:
# I'll help you solve 2x + 3 = 7.
#
# **Step 1:** Subtract 3 from both sides
# - 2x + 3 - 3 = 7 - 3
# - 2x = 4
#
# **Step 2:** Divide both sides by 2
# - 2x ÷ 2 = 4 ÷ 2
# - x = 2
#
# **Answer: x = 2**
#
# To check: 2(2) + 3 = 4 + 3 = 7 ✓
# I'd be happy to help you solve this equation! Let's work through it together.
#
# First, let me ask you: **What do you think our goal is when solving an equation like this?**
#
# Take a look at the equation: 2x + 3 = 7
#
# What are we trying to find?

# %%
messages = []

add_user_message(messages, "Write a function that checks a string for duplicate characters.")
answer = chat(messages, system="You are a Python engineer who writes very concise code.")

print(answer)
# Out:
# Here's a concise function to check for duplicate characters:
#
# ```python
# def has_duplicates(s: str) -> bool:
#     return len(s) != len(set(s))
# ```
#
# **Usage:**
# ```python
# has_duplicates("hello")    # True (l appears twice)
# has_duplicates("world")    # False
# has_duplicates("")         # False
# ```
#
# **Alternative** (if you need to know which characters are duplicated):
# ```python
# def find_duplicates(s: str) -> set:
#     return {c for c in s if s.count(c) > 1}
# ```
