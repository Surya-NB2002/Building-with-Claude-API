# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_011Cd1f9LjV58FNcuXEAZ1iJ', container=None, content=[TextBlock(citations=None, text='The best exercises for gaining leg muscle are compound movements that work multiple muscle groups simultaneously. Here are the top options:\n\n**1. Squats (Back Squats)**\n- Often considered the king of leg exercises\n- Targets quadriceps, glutes, hamstrings, and core\n- Allows for progressive overload with heavy weights\n- Variations include front squats, goblet squats, and Bulgarian split squats\n\n**2. Deadlifts (Romanian/Conventional)**\n- Excellent for posterior chain development (hamstrings, glutes, lower back)\n- Builds overall leg strength and mass\n- Romanian deadlifts especially target hamstrings\n\n**3. Leg Press**\n- Great for targeting quads with heavy weight\n- Safer alternative for those with back issues\n- Allows you to lift heavy without as much stabilization needed\n\n**4. Lunges**\n- Works each leg independently\n- Excellent for balance and correcting muscle imbalances\n- Targets quads, glutes, and hamstrings\n\n**5. Bulgarian Split Squats**\n- Highly effective for building quads and glutes\n- Unilateral exercise that addresses imbalances\n- Can be very challenging even with moderate weight\n\n**Key Principles for Muscle Growth:**\n- **Progressive overload**: Gradually increase weight, reps, or volume\n- **Adequate volume**: 10-20 sets per week for each major leg muscle group\n- **Proper nutrition**: Sufficient protein (0.7-1g per pound of bodyweight) and calories\n- **Recovery**: Allow 48-72 hours between intense leg workouts\n\nIf you had to choose just one exercise, **squats** are generally considered the most effective overall leg builder, but the best program includes a variety of these movements to target all leg muscles comprehensively.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=408, output_tokens_details=None, server_tool_use=None, service_tier='standard'))
