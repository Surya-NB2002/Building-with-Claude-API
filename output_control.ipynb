# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }
    
    if system:
        params["system"] = system

    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "Generate a short user profile example in json format with 5 characteristics")
add_assistant_message(messages, "```json")

text = chat(messages, stop_sequences=["```"])
text
# Out:
# '\n{\n  "userId": "user_12345",\n  "name": "Sarah Chen",\n  "age": 28,\n  "location": "Seattle, WA",\n  "interests": [\n    "photography",\n    "hiking",\n    "coffee"\n  ],\n  "memberSince": "2022-03-15"\n}\n'

# %%
import json

json.loads(text.strip())
# Out:
# {'userId': 'user_12345',
#  'name': 'Sarah Chen',
#  'age': 28,
#  'location': 'Seattle, WA',
#  'interests': ['photography', 'hiking', 'coffee'],
#  'memberSince': '2022-03-15'}

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short.
"""
add_user_message(messages, prompt)
add_assistant_message(messages, "Here are all three commands in a single block without any comments:\n```bash")

text = chat(messages, stop_sequences=["```"]).strip()
text
# Out:
# 'aws s3 ls\n\naws ec2 describe-instances\n\naws iam list-users'

# %%
from IPython.display import Markdown

Markdown(text)
# Out:
# aws s3 ls
#
# aws ec2 describe-instances
#
# aws iam list-users
